# %% [markdown]
# <a href="https://colab.research.google.com/github/Valentine901/Auth-API/blob/master/Gender_Age_Classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files

dataset_path = "/content/dataset"

data = []
gender_labels = []
age_labels = []

for gender in os.listdir(dataset_path):
  gender_path = os.path.join(dataset_path, gender)

  gender_label = 0 if gender == "male" else 1

  for age_group in os.listdir(gender_path):
    age_path = os.path.join(gender_path, age_group)
    age_label = 0 if age_group == "young" else 1


    for img_name in os.listdir(age_path):
      try:
        img_path = os.path.join(age_path, img_name)
        img = cv2.imread(img_path)
        img = cv2.resize(img, (128, 128))

        data.append(img)
        # gender_labels = {"male":0, "female":1}
        gender_labels.append(gender_label)
        # age_labels = {"young":0, "adult":1}
        age_labels.append(age_label)
      except:
        pass


X = np.array(data)
y_gender = np.array(gender_labels)
y_age = np.array(age_labels)

# to normalize the image
X = X / 255.0


# cnn models

model = models.Sequential([

                          #  first convolution layer
layers.Conv2D(32, (3,3), activation="relu", input_shape=(128, 128, 3)),
layers.MaxPooling2D(2,2),

# second convolution layer
layers.Conv2D(64, (3,3), activation="relu"),
layers.MaxPooling2D(2,2),

                          # Third Layer
layers.Conv2D(128, (3,3), activation="relu"),
layers.MaxPooling2D(2,2),

                #convert to 1D
layers.Flatten(),

layers.Dense(128, activation="relu"),

                          # output 2 result age + gender
layers.Dense(2, activation="sigmoid")
])


model.compile(
    # controls learning process
    optimizer="adam",
    # class via binary (e.g; 0 and 1)
    loss="binary_crossentropy",
    # meaure how well it works
    metrics=["accuracy"]
)

y_combined = np.column_stack((y_gender, y_age))

history = model.fit(
    X, y_combined,
    epochs=10,
    batch_size=8
    )


uploaded = files.upload()

for filename in uploaded.keys():
  img = cv2.imread(filename)
  img_resized = cv2.resize(img, (128, 128))
  img_norm = img_resized / 255.0
  img_input = np.reshape(img_norm, (1, 128, 128, 3))

  prediction = model.predict(img_input)[0]

  gender = "Male" if prediction[0] < 0.5 else "Female"
  age = "Young" if prediction[1] < 0.5 else "Adult"

  img_color = cv2.cvtColor(img_resized, cv2.COLOR_BGR2RGB)

  plt.imshow(img_color)
  plt.title(f"Gender: {gender}, Age: {age}")
  plt.axis("off")
  plt.show()
# Out:
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 222ms/step - accuracy: 0.7188 - loss: 0.7966
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 213ms/step - accuracy: 0.2188 - loss: 0.6797
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 0.6250 - loss: 0.6482
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.5312 - loss: 0.5736
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 0.6875 - loss: 0.5318
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.6250 - loss: 0.4195
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 0.7500 - loss: 0.3218
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 213ms/step - accuracy: 0.8125 - loss: 0.2692
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 324ms/step - accuracy: 0.7812 - loss: 0.1774
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 366ms/step - accuracy: 0.7812 - loss: 0.1098
#      <input type="file" id="files-00f85ebf-34ac-44c1-9214-eb5c81e6469f" name="files[]" multiple disabled
# ...
